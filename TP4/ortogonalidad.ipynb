# %%
import json
import numpy as np
from main_hopfield import parse_file
import pandas as pd
import itertools

letters = parse_file()

letters_dict = {}
current_letter = 65
for letter in letters:
    letters_dict[chr(current_letter)] = letter
    current_letter += 1

all_groups = list(itertools.combinations(letters_dict.keys(), r=4))
avg_dot_product = []
max_dot_product = []

for i in range(len(all_groups)):
    group = np.array([v for k,v in letters_dict.items() if k in all_groups[i]])
    orto_matrix = group.dot(group.T)
    np.fill_diagonal(orto_matrix, 0)
    #print(f'{all_groups[i]}\n{orto_matrix}\n-------------------------------------')
    row, _ = orto_matrix.shape
    avg_dot_product.append((np.abs(orto_matrix).sum() / (orto_matrix.size - row), all_groups[i]))
    max_v = np.abs(orto_matrix).max()
    max_dot_product.append(((max_v, np.count_nonzero(np.abs(orto_matrix) == max_v) / 2), all_groups[i]))

df = pd.DataFrame(sorted(avg_dot_product), columns=["|<,>| medio", "grupo"])
df.head(15).style.format({'|<,>| medio': "{:.2f}"}).hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d8cae">
#   <thead>
#     <tr>
#       <th id="T_d8cae_level0_col0" class="col_heading level0 col0" >|<,>| medio</th>
#       <th id="T_d8cae_level0_col1" class="col_heading level0 col1" >grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d8cae_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_d8cae_row0_col1" class="data row0 col1" >('R', 'T', 'V', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row1_col0" class="data row1 col0" >1.33</td>
#       <td id="T_d8cae_row1_col1" class="data row1 col1" >('A', 'K', 'M', 'S')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row2_col0" class="data row2 col0" >1.33</td>
#       <td id="T_d8cae_row2_col1" class="data row2 col1" >('K', 'N', 'S', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row3_col0" class="data row3 col0" >1.33</td>
#       <td id="T_d8cae_row3_col1" class="data row3 col1" >('L', 'R', 'T', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row4_col0" class="data row4 col0" >1.67</td>
#       <td id="T_d8cae_row4_col1" class="data row4 col1" >('B', 'K', 'N', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row5_col0" class="data row5 col0" >1.67</td>
#       <td id="T_d8cae_row5_col1" class="data row5 col1" >('I', 'P', 'Q', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row6_col0" class="data row6 col0" >1.67</td>
#       <td id="T_d8cae_row6_col1" class="data row6 col1" >('I', 'R', 'W', 'Y')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row7_col0" class="data row7 col0" >1.67</td>
#       <td id="T_d8cae_row7_col1" class="data row7 col1" >('I', 'R', 'X', 'Y')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row8_col0" class="data row8 col0" >1.67</td>
#       <td id="T_d8cae_row8_col1" class="data row8 col1" >('K', 'M', 'S', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row9_col0" class="data row9 col0" >1.67</td>
#       <td id="T_d8cae_row9_col1" class="data row9 col1" >('K', 'M', 'S', 'Y')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row10_col0" class="data row10 col0" >1.67</td>
#       <td id="T_d8cae_row10_col1" class="data row10 col1" >('K', 'N', 'S', 'Y')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row11_col0" class="data row11 col0" >1.67</td>
#       <td id="T_d8cae_row11_col1" class="data row11 col1" >('K', 'S', 'T', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row12_col0" class="data row12 col0" >1.67</td>
#       <td id="T_d8cae_row12_col1" class="data row12 col1" >('L', 'R', 'T', 'X')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row13_col0" class="data row13 col0" >1.67</td>
#       <td id="T_d8cae_row13_col1" class="data row13 col1" >('M', 'P', 'Q', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_d8cae_row14_col0" class="data row14 col0" >1.67</td>
#       <td id="T_d8cae_row14_col1" class="data row14 col1" >('P', 'T', 'V', 'W')</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.tail(15).style.format({'|<,>| medio': "{:.2f}"}).hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_fb44e">
#   <thead>
#     <tr>
#       <th id="T_fb44e_level0_col0" class="col_heading level0 col0" >|<,>| medio</th>
#       <th id="T_fb44e_level0_col1" class="col_heading level0 col1" >grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fb44e_row0_col0" class="data row0 col0" >15.33</td>
#       <td id="T_fb44e_row0_col1" class="data row0 col1" >('D', 'G', 'O', 'S')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row1_col0" class="data row1 col0" >15.33</td>
#       <td id="T_fb44e_row1_col1" class="data row1 col1" >('D', 'G', 'O', 'U')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row2_col0" class="data row2 col0" >15.67</td>
#       <td id="T_fb44e_row2_col1" class="data row2 col1" >('B', 'D', 'E', 'O')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row3_col0" class="data row3 col0" >15.67</td>
#       <td id="T_fb44e_row3_col1" class="data row3 col1" >('B', 'D', 'O', 'S')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row4_col0" class="data row4 col0" >15.67</td>
#       <td id="T_fb44e_row4_col1" class="data row4 col1" >('B', 'D', 'O', 'U')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row5_col0" class="data row5 col0" >15.67</td>
#       <td id="T_fb44e_row5_col1" class="data row5 col1" >('B', 'F', 'P', 'R')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row6_col0" class="data row6 col0" >15.67</td>
#       <td id="T_fb44e_row6_col1" class="data row6 col1" >('C', 'E', 'G', 'O')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row7_col0" class="data row7 col0" >15.67</td>
#       <td id="T_fb44e_row7_col1" class="data row7 col1" >('E', 'F', 'P', 'R')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row8_col0" class="data row8 col0" >16.00</td>
#       <td id="T_fb44e_row8_col1" class="data row8 col1" >('B', 'D', 'G', 'O')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row9_col0" class="data row9 col0" >16.00</td>
#       <td id="T_fb44e_row9_col1" class="data row9 col1" >('C', 'D', 'G', 'O')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row10_col0" class="data row10 col0" >16.00</td>
#       <td id="T_fb44e_row10_col1" class="data row10 col1" >('C', 'D', 'O', 'Q')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row11_col0" class="data row11 col0" >16.00</td>
#       <td id="T_fb44e_row11_col1" class="data row11 col1" >('D', 'O', 'Q', 'U')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row12_col0" class="data row12 col0" >16.67</td>
#       <td id="T_fb44e_row12_col1" class="data row12 col1" >('B', 'D', 'O', 'Q')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row13_col0" class="data row13 col0" >16.67</td>
#       <td id="T_fb44e_row13_col1" class="data row13 col1" >('C', 'G', 'O', 'Q')</td>
#     </tr>
#     <tr>
#       <td id="T_fb44e_row14_col0" class="data row14 col0" >17.00</td>
#       <td id="T_fb44e_row14_col1" class="data row14 col1" >('D', 'G', 'O', 'Q')</td>
#     </tr>
#   </tbody>
# </table>

# %%
df2 = pd.DataFrame(sorted(max_dot_product), columns=["|<,>| max", "grupo"])
df2.head(15).style.format({'|<,>| max': lambda x: 'max: {:,.0f} | count: {:,.0f}'.format(*x)}).hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_dfa78">
#   <thead>
#     <tr>
#       <th id="T_dfa78_level0_col0" class="col_heading level0 col0" >|<,>| max</th>
#       <th id="T_dfa78_level0_col1" class="col_heading level0 col1" >grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_dfa78_row0_col0" class="data row0 col0" >max: 1 | count: 6</td>
#       <td id="T_dfa78_row0_col1" class="data row0 col1" >('R', 'T', 'V', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row1_col0" class="data row1 col0" >max: 3 | count: 1</td>
#       <td id="T_dfa78_row1_col1" class="data row1 col1" >('A', 'K', 'M', 'S')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row2_col0" class="data row2 col0" >max: 3 | count: 1</td>
#       <td id="T_dfa78_row2_col1" class="data row2 col1" >('K', 'N', 'S', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row3_col0" class="data row3 col0" >max: 3 | count: 1</td>
#       <td id="T_dfa78_row3_col1" class="data row3 col1" >('L', 'R', 'T', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row4_col0" class="data row4 col0" >max: 3 | count: 2</td>
#       <td id="T_dfa78_row4_col1" class="data row4 col1" >('B', 'K', 'N', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row5_col0" class="data row5 col0" >max: 3 | count: 2</td>
#       <td id="T_dfa78_row5_col1" class="data row5 col1" >('K', 'M', 'S', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row6_col0" class="data row6 col0" >max: 3 | count: 2</td>
#       <td id="T_dfa78_row6_col1" class="data row6 col1" >('K', 'S', 'T', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row7_col0" class="data row7 col0" >max: 3 | count: 2</td>
#       <td id="T_dfa78_row7_col1" class="data row7 col1" >('M', 'P', 'Q', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row8_col0" class="data row8 col0" >max: 3 | count: 2</td>
#       <td id="T_dfa78_row8_col1" class="data row8 col1" >('P', 'T', 'V', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row9_col0" class="data row9 col0" >max: 3 | count: 2</td>
#       <td id="T_dfa78_row9_col1" class="data row9 col1" >('S', 'T', 'V', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row10_col0" class="data row10 col0" >max: 3 | count: 3</td>
#       <td id="T_dfa78_row10_col1" class="data row10 col1" >('A', 'B', 'K', 'M')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row11_col0" class="data row11 col0" >max: 3 | count: 3</td>
#       <td id="T_dfa78_row11_col1" class="data row11 col1" >('A', 'J', 'K', 'S')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row12_col0" class="data row12 col0" >max: 3 | count: 3</td>
#       <td id="T_dfa78_row12_col1" class="data row12 col1" >('A', 'J', 'K', 'U')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row13_col0" class="data row13 col0" >max: 3 | count: 3</td>
#       <td id="T_dfa78_row13_col1" class="data row13 col1" >('B', 'K', 'M', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_dfa78_row14_col0" class="data row14 col0" >max: 3 | count: 3</td>
#       <td id="T_dfa78_row14_col1" class="data row14 col1" >('B', 'K', 'T', 'V')</td>
#     </tr>
#   </tbody>
# </table>

# %%
df3 = df2.merge(df)
df3 = df3[['|<,>| max', '|<,>| medio', 'grupo']]
df3.head(15).style.format({'|<,>| max': lambda x: 'max: {:,.0f} | count: {:,.0f}'.format(*x), '|<,>| medio':"{:.2f}"}).hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c322">
#   <thead>
#     <tr>
#       <th id="T_3c322_level0_col0" class="col_heading level0 col0" >|<,>| max</th>
#       <th id="T_3c322_level0_col1" class="col_heading level0 col1" >|<,>| medio</th>
#       <th id="T_3c322_level0_col2" class="col_heading level0 col2" >grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3c322_row0_col0" class="data row0 col0" >max: 1 | count: 6</td>
#       <td id="T_3c322_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_3c322_row0_col2" class="data row0 col2" >('R', 'T', 'V', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row1_col0" class="data row1 col0" >max: 3 | count: 1</td>
#       <td id="T_3c322_row1_col1" class="data row1 col1" >1.33</td>
#       <td id="T_3c322_row1_col2" class="data row1 col2" >('A', 'K', 'M', 'S')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row2_col0" class="data row2 col0" >max: 3 | count: 1</td>
#       <td id="T_3c322_row2_col1" class="data row2 col1" >1.33</td>
#       <td id="T_3c322_row2_col2" class="data row2 col2" >('K', 'N', 'S', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row3_col0" class="data row3 col0" >max: 3 | count: 1</td>
#       <td id="T_3c322_row3_col1" class="data row3 col1" >1.33</td>
#       <td id="T_3c322_row3_col2" class="data row3 col2" >('L', 'R', 'T', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row4_col0" class="data row4 col0" >max: 3 | count: 2</td>
#       <td id="T_3c322_row4_col1" class="data row4 col1" >1.67</td>
#       <td id="T_3c322_row4_col2" class="data row4 col2" >('B', 'K', 'N', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row5_col0" class="data row5 col0" >max: 3 | count: 2</td>
#       <td id="T_3c322_row5_col1" class="data row5 col1" >1.67</td>
#       <td id="T_3c322_row5_col2" class="data row5 col2" >('K', 'M', 'S', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row6_col0" class="data row6 col0" >max: 3 | count: 2</td>
#       <td id="T_3c322_row6_col1" class="data row6 col1" >1.67</td>
#       <td id="T_3c322_row6_col2" class="data row6 col2" >('K', 'S', 'T', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row7_col0" class="data row7 col0" >max: 3 | count: 2</td>
#       <td id="T_3c322_row7_col1" class="data row7 col1" >1.67</td>
#       <td id="T_3c322_row7_col2" class="data row7 col2" >('M', 'P', 'Q', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row8_col0" class="data row8 col0" >max: 3 | count: 2</td>
#       <td id="T_3c322_row8_col1" class="data row8 col1" >1.67</td>
#       <td id="T_3c322_row8_col2" class="data row8 col2" >('P', 'T', 'V', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row9_col0" class="data row9 col0" >max: 3 | count: 2</td>
#       <td id="T_3c322_row9_col1" class="data row9 col1" >1.67</td>
#       <td id="T_3c322_row9_col2" class="data row9 col2" >('S', 'T', 'V', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row10_col0" class="data row10 col0" >max: 3 | count: 3</td>
#       <td id="T_3c322_row10_col1" class="data row10 col1" >2.00</td>
#       <td id="T_3c322_row10_col2" class="data row10 col2" >('A', 'B', 'K', 'M')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row11_col0" class="data row11 col0" >max: 3 | count: 3</td>
#       <td id="T_3c322_row11_col1" class="data row11 col1" >2.00</td>
#       <td id="T_3c322_row11_col2" class="data row11 col2" >('A', 'J', 'K', 'S')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row12_col0" class="data row12 col0" >max: 3 | count: 3</td>
#       <td id="T_3c322_row12_col1" class="data row12 col1" >2.00</td>
#       <td id="T_3c322_row12_col2" class="data row12 col2" >('A', 'J', 'K', 'U')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row13_col0" class="data row13 col0" >max: 3 | count: 3</td>
#       <td id="T_3c322_row13_col1" class="data row13 col1" >2.00</td>
#       <td id="T_3c322_row13_col2" class="data row13 col2" >('B', 'K', 'M', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_3c322_row14_col0" class="data row14 col0" >max: 3 | count: 3</td>
#       <td id="T_3c322_row14_col1" class="data row14 col1" >2.00</td>
#       <td id="T_3c322_row14_col2" class="data row14 col2" >('B', 'K', 'T', 'V')</td>
#     </tr>
#   </tbody>
# </table>

# %%
df3.tail(25).style.format({'|<,>| max': lambda x: 'max: {:,.0f} | count: {:,.0f}'.format(*x), '|<,>| medio': "{:.2f}"}).hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_1d31d">
#   <thead>
#     <tr>
#       <th id="T_1d31d_level0_col0" class="col_heading level0 col0" >|<,>| max</th>
#       <th id="T_1d31d_level0_col1" class="col_heading level0 col1" >|<,>| medio</th>
#       <th id="T_1d31d_level0_col2" class="col_heading level0 col2" >grupo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1d31d_row0_col0" class="data row0 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row0_col1" class="data row0 col1" >8.33</td>
#       <td id="T_1d31d_row0_col2" class="data row0 col2" >('P', 'R', 'S', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row1_col0" class="data row1 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row1_col1" class="data row1 col1" >5.00</td>
#       <td id="T_1d31d_row1_col2" class="data row1 col2" >('P', 'R', 'T', 'U')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row2_col0" class="data row2 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row2_col1" class="data row2 col1" >5.00</td>
#       <td id="T_1d31d_row2_col2" class="data row2 col2" >('P', 'R', 'T', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row3_col0" class="data row3 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row3_col1" class="data row3 col1" >4.67</td>
#       <td id="T_1d31d_row3_col2" class="data row3 col2" >('P', 'R', 'T', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row4_col0" class="data row4 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row4_col1" class="data row4 col1" >6.00</td>
#       <td id="T_1d31d_row4_col2" class="data row4 col2" >('P', 'R', 'T', 'X')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row5_col0" class="data row5 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row5_col1" class="data row5 col1" >6.33</td>
#       <td id="T_1d31d_row5_col2" class="data row5 col2" >('P', 'R', 'T', 'Y')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row6_col0" class="data row6 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row6_col1" class="data row6 col1" >6.00</td>
#       <td id="T_1d31d_row6_col2" class="data row6 col2" >('P', 'R', 'T', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row7_col0" class="data row7 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row7_col1" class="data row7 col1" >5.33</td>
#       <td id="T_1d31d_row7_col2" class="data row7 col2" >('P', 'R', 'U', 'V')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row8_col0" class="data row8 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row8_col1" class="data row8 col1" >7.33</td>
#       <td id="T_1d31d_row8_col2" class="data row8 col2" >('P', 'R', 'U', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row9_col0" class="data row9 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row9_col1" class="data row9 col1" >6.67</td>
#       <td id="T_1d31d_row9_col2" class="data row9 col2" >('P', 'R', 'U', 'X')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row10_col0" class="data row10 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row10_col1" class="data row10 col1" >6.00</td>
#       <td id="T_1d31d_row10_col2" class="data row10 col2" >('P', 'R', 'U', 'Y')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row11_col0" class="data row11 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row11_col1" class="data row11 col1" >4.67</td>
#       <td id="T_1d31d_row11_col2" class="data row11 col2" >('P', 'R', 'U', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row12_col0" class="data row12 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row12_col1" class="data row12 col1" >4.67</td>
#       <td id="T_1d31d_row12_col2" class="data row12 col2" >('P', 'R', 'V', 'W')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row13_col0" class="data row13 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row13_col1" class="data row13 col1" >6.67</td>
#       <td id="T_1d31d_row13_col2" class="data row13 col2" >('P', 'R', 'V', 'X')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row14_col0" class="data row14 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row14_col1" class="data row14 col1" >8.33</td>
#       <td id="T_1d31d_row14_col2" class="data row14 col2" >('P', 'R', 'V', 'Y')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row15_col0" class="data row15 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row15_col1" class="data row15 col1" >5.00</td>
#       <td id="T_1d31d_row15_col2" class="data row15 col2" >('P', 'R', 'V', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row16_col0" class="data row16 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row16_col1" class="data row16 col1" >6.33</td>
#       <td id="T_1d31d_row16_col2" class="data row16 col2" >('P', 'R', 'W', 'X')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row17_col0" class="data row17 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row17_col1" class="data row17 col1" >5.67</td>
#       <td id="T_1d31d_row17_col2" class="data row17 col2" >('P', 'R', 'W', 'Y')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row18_col0" class="data row18 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row18_col1" class="data row18 col1" >5.00</td>
#       <td id="T_1d31d_row18_col2" class="data row18 col2" >('P', 'R', 'W', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row19_col0" class="data row19 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row19_col1" class="data row19 col1" >6.33</td>
#       <td id="T_1d31d_row19_col2" class="data row19 col2" >('P', 'R', 'X', 'Y')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row20_col0" class="data row20 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row20_col1" class="data row20 col1" >7.00</td>
#       <td id="T_1d31d_row20_col2" class="data row20 col2" >('P', 'R', 'X', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row21_col0" class="data row21 col0" >max: 21 | count: 1</td>
#       <td id="T_1d31d_row21_col1" class="data row21 col1" >5.67</td>
#       <td id="T_1d31d_row21_col2" class="data row21 col2" >('P', 'R', 'Y', 'Z')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row22_col0" class="data row22 col0" >max: 21 | count: 2</td>
#       <td id="T_1d31d_row22_col1" class="data row22 col1" >10.33</td>
#       <td id="T_1d31d_row22_col2" class="data row22 col2" >('D', 'M', 'N', 'O')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row23_col0" class="data row23 col0" >max: 21 | count: 2</td>
#       <td id="T_1d31d_row23_col1" class="data row23 col1" >12.33</td>
#       <td id="T_1d31d_row23_col2" class="data row23 col2" >('D', 'O', 'P', 'R')</td>
#     </tr>
#     <tr>
#       <td id="T_1d31d_row24_col0" class="data row24 col0" >max: 21 | count: 2</td>
#       <td id="T_1d31d_row24_col1" class="data row24 col1" >10.33</td>
#       <td id="T_1d31d_row24_col2" class="data row24 col2" >('M', 'N', 'P', 'R')</td>
#     </tr>
#   </tbody>
# </table>
